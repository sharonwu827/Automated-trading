# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # March 2
# ## 3 Coins combine  BTC+BNB+ETH, Morning, Evening, [open,high,low,close,volumeto]

# %%
# %run main.py -mode=gasf+cnn -targets=3COIN_USD -sample_size=3000 -feature_channels=open,high,low,close,volumeto
# Out:
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# ...

# %% [markdown]
# # March 3

# %% [markdown]
# ## BTC, Morning, Evening, [open,high,low,close,volumeto]

# %%
# %run main.py -mode=cnn -targets=BTC_USD -sample_size=1000 -feature_channels=open,high,low,close,volumeto
# Out:
# /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# ...

# %% [markdown]
# ## ETH, Morning, Evening, [open,high,low,close,volumeto]

# %%
# %run main.py -mode=cnn -targets=ETH_USD -sample_size=1000 -feature_channels=open,high,low,close,volumeto
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ## BNB, Morning, Evening, [open,high,low,close,volumeto]

# %%
# %run main.py -mode=gasf+cnn -targets=BNB_USD -sample_size=900 -feature_channels=open,high,low,close,volumeto
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# # March 3 After fix rolling error
# ### BTC Morning, Evening Classifier

# %%
# %run main.py -mode=csv_pattern+gasf+cnn -targets=BTC_USD -sample_size=1000 -feature_channels=open,high,low,close,volumeto
# Out:
# Rule : 1H
# Period : 2017-04-28 18:00:00 - 2022-02-07 06:00:00
#
# Number of MorningStar : 2656 // 42021
#
# Number of EveningStar : 1093 // 42021
#
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# ...

# %% [markdown]
# ### ETH

# %%
# %run main.py -mode=csv_pattern+gasf+cnn -targets=ETH_USD -sample_size=1000 -feature_channels=open,high,low,close,volumeto
# Out:
# Rule : 1H
# Period : 2017-04-27 21:00:00 - 2022-02-07 05:00:00
#
# Number of MorningStar : 2609 // 42021
#
# Number of EveningStar : 1052 // 42021
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# ...

# %% [markdown]
# ### BNB

# %%
# %run main.py -mode=csv_pattern+gasf+cnn -targets=BNB_USD -sample_size=900 -feature_channels=open,high,low,close,volumeto
# Out:
# Rule : 1H
# Period : 2017-11-01 23:00:00 - 2022-02-28 06:00:00
#
# Number of MorningStar : 2144 // 38019
#
# Number of EveningStar : 909 // 38019
#
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# ...

# %% [markdown]
# # March 4

# %% [markdown]
# ### 3Coin  3Category  M E N

# %%
# %run main.py -mode=cnn -targets=3COIN_USD -sample_size=1000 -feature_channels=open,high,low,close,volumeto -pattern_ls=MorningStar,EveningStar -ignore_patternless=False
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 32)          0
# ...

# %% [markdown]
# ### 3Coin 2Category Mg Mb

# %%
# %run main.py -mode=gasf+cnn -targets=3COIN_USD -sample_size=1000 -feature_channels=open,high,low,close,volumeto -pattern_ls=MorningStar_good,MorningStar_bad
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 3Coin 2Category Eg Eb

# %%
# %run main.py -mode=gasf+cnn -targets=3COIN_USD -sample_size=750 -feature_channels=open,high,low,close,volumeto -pattern_ls=EveningStar_good,EveningStar_bad
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 3Coin 5Category

# %%
# %run main.py -mode=gasf+cnn -targets=3COIN_USD -sample_size=750 -feature_channels=open,high,low,close,volumeto -ignore_patternless=False
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# # March 4 with Social Data
# ## csv download and pattern
# ### BTC

# %%
# %run main.py -mode=csv_download+csv_pattern -targets=BTC_USD -start_date=2017-04-29 -end_date=2022-03-01
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1646114400}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1638936000.0}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1631754000.0}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# ...

# %% [markdown]
# ### ETH

# %%
# %run main.py -mode=csv_download+csv_pattern -targets=ETH_USD -start_date=2017-04-29 -end_date=2022-03-01
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1646114400}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1638936000.0}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1631754000.0}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# ...

# %% [markdown]
# ### BNB

# %%
# %run main.py -mode=csv_download+csv_pattern -targets=BNB_USD -start_date=2017-04-29 -end_date=2022-03-01
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BNB', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1646114400}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BNB', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1638936000.0}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BNB', 'tsym': 'USD', 'limit': 2000, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1631754000.0}
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# ...

# %% [markdown]
# ### 2COIN（BTC+ETH）

# %%
# %run main.py -mode=gasf+cnn -targets=2COIN_USD -sample_size=530 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_9 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# ...
