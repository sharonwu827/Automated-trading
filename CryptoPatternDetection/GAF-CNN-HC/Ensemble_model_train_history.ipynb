# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # March 10
# ## 9 Features M E No
# ### 8Coin 3Category 1200(M, E, No) Batch 800, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_9 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 800, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 32)          0
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 1000, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 32)          0
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 1000, Epoch 500, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 300, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 800, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 500, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 1000, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN9F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -ignore_patternless=False
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        1184
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ## 5 Features M E No
# ### 8Coin 3Category 1200(M, E, No) Batch 500, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN5F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto -ignore_patternless=False
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 800, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN5F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto -ignore_patternless=False
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 1000, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN5F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low,volumeto -ignore_patternless=False
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ## 4 Features M E No
# ### 8Coin 3Category 1200(M, E, No) Batch 500, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN4F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low -ignore_patternless=False
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 10, 10, 32)        544
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 800, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN4F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low -ignore_patternless=False
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 10, 10, 32)        544
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# ### 8Coin 3Category 1200(M, E, No) Batch 1000, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMEN4F_USD -sample_size=1200 -pattern_ls=MorningStar,EveningStar -feature_channels=open,high,close,low -ignore_patternless=False
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 10, 10, 32)        544
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# # March 11
# ## Morning Good Vs Morning Bad 9-4 features Volumn ～ Pageviews

# %% [markdown]
# ### 8Coin 2Category 1200(MG, MB) Batch 800, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINMGB9-4F_USD -sample_size=1200 -pattern_ls=MorningStar_good,MorningStar_bad -feature_channels=volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views
# Out:
# /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# ...

# %% [markdown]
# ## Evening Good Vs Evening Bad 9-4 features Volumn ～ Pageviews

# %% [markdown]
# ### 8Coin 2Category 1200(EG, EB) Batch 800, Epoch 300, defaultNN

# %%
# %run main.py -mode=cnn -targets=8COINEGB9-4F_USD -sample_size=1200 -pattern_ls=EveningStar_good,EveningStar_bad -feature_channels=volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        672
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 32)          4128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# ...

# %% [markdown]
# # The end
