# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # April 5
# ## BTC

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=BTC_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649215340}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649215340}
# tracking <tf.Variable 'Variable_4:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_5:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_6:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_7:0' shape=() dtype=int32> fn
# Buy:/n
# DatetimeIndex(['2022-04-05 12:00:00', '2022-04-05 16:00:00',
#                '2022-04-05 17:00:00', '2022-04-05 18:00:00',
#                '2022-04-05 19:00:00', '2022-04-05 20:00:00',
#                '2022-04-05 21:00:00', '2022-04-05 22:00:00',
# ...

# %% [markdown]
# ## ETH

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649215388}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649215388}
# tracking <tf.Variable 'Variable_8:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_9:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_10:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_11:0' shape=() dtype=int32> fn
# Buy:/n
# DatetimeIndex(['2022-04-05 15:00:00', '2022-04-05 16:00:00',
#                '2022-04-05 17:00:00', '2022-04-05 18:00:00',
#                '2022-04-05 19:00:00', '2022-04-05 20:00:00',
#                '2022-04-05 21:00:00', '2022-04-05 22:00:00',
# ...

# %% [markdown]
# ## April 6  Morning

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=BTC_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649229064}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649229064}
# tracking <tf.Variable 'Variable_8:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_9:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_10:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_11:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-05 16:00:00    45923.77
# 2022-04-05 17:00:00    45973.65
# 2022-04-05 18:00:00    45900.46
# 2022-04-05 19:00:00    46033.52
# 2022-04-05 20:00:00    45876.40
# 2022-04-05 21:00:00    45956.63
# 2022-04-05 22:00:00    45855.44
# ...

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649229069}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649229069}
# tracking <tf.Variable 'Variable_12:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_13:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_14:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_15:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-05 16:00:00    3463.95
# 2022-04-05 17:00:00    3451.33
# 2022-04-05 18:00:00    3445.62
# 2022-04-05 19:00:00    3464.27
# 2022-04-05 20:00:00    3441.23
# 2022-04-05 21:00:00    3453.40
# 2022-04-05 22:00:00    3444.23
# ...

# %% [markdown]
# ## April 6  Morning

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=BTC_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# Using TensorFlow backend.
# /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649275469}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649275469}
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32> tp
# ...

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649275474}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649275474}
# tracking <tf.Variable 'Variable_4:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_5:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_6:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_7:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-06 05:00:00    3368.45
# 2022-04-06 06:00:00    3368.69
# 2022-04-06 08:00:00    3357.61
# 2022-04-06 15:00:00    3256.36
# 2022-04-06 16:00:00    3211.88
# 2022-04-06 17:00:00    3219.84
# 2022-04-06 18:00:00    3238.45
# ...

# %% [markdown]
# ## April 7

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=BTC_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# Using TensorFlow backend.
# /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649357127}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649357127}
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32> tp
# ...

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649357137}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649357137}
# tracking <tf.Variable 'Variable_4:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_5:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_6:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_7:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-07 04:00:00    3207.05
# 2022-04-07 05:00:00    3218.73
# 2022-04-07 06:00:00    3214.02
# 2022-04-07 16:00:00    3220.27
# 2022-04-07 17:00:00    3225.88
# 2022-04-07 18:00:00    3231.06
# Name: close, dtype: float64
# Sell:
# datetime
# ...

# %% [markdown]
# ## April 8

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=BTC_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# Using TensorFlow backend.
# /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649445555}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649445555}
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32> tp
# ...

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649445558}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649445558}
# tracking <tf.Variable 'Variable_4:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_5:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_6:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_7:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-08 14:00:00    3292.52
# 2022-04-08 15:00:00    3282.10
# Name: close, dtype: float64
# Sell:
# datetime
# 2022-04-08 04:00:00    3258.65
# 2022-04-08 06:00:00    3266.93
# 2022-04-08 07:00:00    3286.10
# 2022-04-08 09:00:00    3290.39
# ...

# %% [markdown]
# ## April 9

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=BTC_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# Using TensorFlow backend.
# /Users/haoyuzhang/anaconda3/envs/Kerasenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649531754}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649531754}
# tracking <tf.Variable 'Variable:0' shape=() dtype=int32> tp
# ...

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649531759}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649531759}
# tracking <tf.Variable 'Variable_4:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_5:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_6:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_7:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-09 04:00:00    3208.17
# 2022-04-09 05:00:00    3226.27
# 2022-04-09 12:00:00    3229.50
# 2022-04-09 17:00:00    3242.18
# Name: close, dtype: float64
# Sell:
# datetime
# 2022-04-09 06:00:00    3202.87
# 2022-04-09 10:00:00    3211.73
# ...

# %% [markdown]
# ## April 10

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=BTC_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'BTC', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649626665}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649626665}
# tracking <tf.Variable 'Variable_8:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_9:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_10:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_11:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-10 11:00:00    42706.11
# 2022-04-10 12:00:00    42605.14
# 2022-04-10 13:00:00    42594.09
# 2022-04-10 14:00:00    42711.22
# 2022-04-10 15:00:00    42767.18
# 2022-04-10 16:00:00    42801.70
# 2022-04-10 17:00:00    43124.86
# ...

# %%
# %run portfolio.py -model_output='./temp/BTC_USD_result.csv' -cash=100000
# Out:
# =====Transaction=====
#
# From 2022-04-09 21:00:00 to 2022-04-10 21:00:00:
# Buy 1 Coin at 2022-04-10 11:00:00 with the price of 42706.11
# Buy 1 Coin at 2022-04-10 12:00:00 with the price of 42605.14
# Sell 2 Coin(s) at 2022-04-10 17:00:00 with the price of 43124.86
#
# =====Summary=====
#
# From 2022-04-09 21:00:00 to 2022-04-10 21:00:00:
# Cash $100938.47, Coins 0
# Cost $100000.00, Income $100938.47, Rate of income 0.938%

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=1 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649626669}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 24, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649626669}
# tracking <tf.Variable 'Variable_12:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_13:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_14:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_15:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-10 08:00:00    3244.21
# 2022-04-10 09:00:00    3241.54
# 2022-04-10 10:00:00    3245.71
# 2022-04-10 11:00:00    3252.95
# 2022-04-10 12:00:00    3244.69
# 2022-04-10 15:00:00    3257.32
# 2022-04-10 16:00:00    3279.60
# ...

# %%
# %run portfolio.py
# Out:
# =====Transaction=====
#
# From 2022-04-09 21:00:00 to 2022-04-10 21:00:00:
# Buy 1 Coin at 2022-04-10 08:00:00 with the price of 3244.21
# Buy 1 Coin at 2022-04-10 09:00:00 with the price of 3241.54
# Sell 2 Coin(s) at 2022-04-10 16:00:00 with the price of 3279.6
# Buy 1 Coin at 2022-04-10 17:00:00 with the price of 3296.73
#
# =====Summary=====
#
# From 2022-04-09 21:00:00 to 2022-04-10 21:00:00:
# Cash $6776.72, Coins 1
# Cost $10000.00, Income $10058.88, Rate of income 0.589%

# %% [markdown]
# ## April 6 - April 10

# %%
# %run detect.py -mode=realtime+process+predict+display -targets=ETH_USD -look_back=5 -feature_channels=open,high,close,low,volumeto,reddit_active_users,reddit_posts_per_hour,posts,total_page_views -filter_model=False 
# %run portfolio.py
# Out:
# baseurl:  https://min-api.cryptocompare.com/data/v2/histohour
# timeframe:  hour
# parameters:  {'fsym': 'ETH', 'tsym': 'USD', 'limit': 120, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'aggregate': 1, 'toTs': 1649636382}
# baseurl:  https://min-api.cryptocompare.com/data/social/coin/histo/hour
# timeframe:  hour
# parameters:  {'limit': 120, 'api_key': 'dfa3e8f0e629d438b183f88b44be15b16d5c2ef8664e12000f658a996e5656f9', 'toTs': 1649636382}
# tracking <tf.Variable 'Variable_40:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_41:0' shape=() dtype=int32> fp
# tracking <tf.Variable 'Variable_42:0' shape=() dtype=int32> tp
# tracking <tf.Variable 'Variable_43:0' shape=() dtype=int32> fn
# Buy:
# datetime
# 2022-04-06 15:00:00    3256.36
# 2022-04-06 16:00:00    3211.88
# 2022-04-06 17:00:00    3219.84
# 2022-04-06 18:00:00    3238.45
# 2022-04-06 19:00:00    3224.21
# 2022-04-06 20:00:00    3234.37
# 2022-04-06 21:00:00    3227.81
# ...
